# %%
print('hello')
# Out:
# hello

# %%
import pandas as pd

# %%
df=pd.read_csv("BTech_2020-converted.csv")
df
# Out:
#     JEE(Adv) Roll No.  IITG Roll No.                      Name  \
# 0    Preparatory 2019      200106050             PRAGYA THAKUR
# 1    Preparatory 2019      200122017      BANOTH MANASACHANDRA
# 2    Preparatory 2019      200104060            MD SHADAB ALAM
# 3    Preparatory 2019      200104108  SUBHRANSU SEKHAR KHUNTIA
# 4    Preparatory 2019      200102093                    SWASTI
# ..                ...            ...                       ...
# 886           7084130      200108056              VATAN NARANG
# 887           7084250      200106054            RUCHIKA RUHELA
# 888           7085012      200108001              AASTHA SINGH
# 889           7088245      200123025            JASH KUMAR ROY
# 890           7089004      200121035            NIHARIKA SINGH
#
#                                      Programme
# 0               Biosciences and Bioengineering
# 1              Chemical Science and Technology
# 2                            Civil Engineering
# ...

# %%
df.Name.value_counts()
# Out:
# VISHAL KUMAR        3
# DEEPANSHU           2
# PIYUSH KUMAR        2
# SUMIT KUMAR         2
# ARYAN SINGH         2
#                    ..
# SARTHAK AGASHE      1
# AYUSHI ANAND        1
# JUMAN DAS           1
# NITESH SINGH        1
# PRANJAL BARANWAL    1
# Name: Name, Length: 878, dtype: int64

# %%
df.Name[0].split(" ")
# Out:
# ['PRAGYA', 'THAKUR']

# %%
df.drop(df[df.Programme !="Computer Science and Engineering"].index, inplace=True)
df1 = df.reset_index(drop=True)
df1
# Out:
#     JEE(Adv) Roll No.  IITG Roll No.                        Name  \
# 0             1004120      200101076    PATEL HETANG SANJAYKUMAR
# 1             1013044      200101008                ADITYA PATEL
# 2             1026015      200101075  PATEL BHOOMIRAJ RANJITBHAI
# 3             1027062      200101107               VIRAJ GOYANKA
# 4             1031218      200101085                     PRANSHU
# ..                ...            ...                         ...
# 109           7039124      200101016             ANMOLDEEP SINGH
# 110           7048092      200101013          AMIT SINGH NAGNYAL
# 111           7067036      200101033                GAURAV KUMAR
# 112           7078128      200101044            HRIDYANSHU KUMAR
# 113           7083080      200101006              ABHISHEK KUMAR
#
#                             Programme
# 0    Computer Science and Engineering
# 1    Computer Science and Engineering
# 2    Computer Science and Engineering
# ...

# %%
df1.sort_values("Name", axis = 0, ascending = True, 
                 inplace = True, na_position ='last') 
# df1.sort_values(by="Name"), 
                 
df1
# Out:
#     JEE(Adv) Roll No.  IITG Roll No.                     Name  \
# 41            2102273      200101001           AADARSHRAJ SAH
# 26            2055894      200101002       AADI AARYA CHANDRA
# 86            6110009      200101003         ABBURI CHARISHMA
# 36            2100022      200101004            ABHINAV AYUSH
# 47            3013247      200101005  ABHINAV KUMAR CHOUDHARY
# ..                ...            ...                      ...
# 40            2101321      200101110             VISHAL MEENA
# 76            6042052      200101111  YAKKALA HEMA VENKAT RAO
# 37            2100085      200101112             YASH AGARWAL
# 105           7026161      200101113                YASH GARG
# 85            6105031      200101114     YENUGONDA SUMA SHREE
#
#                             Programme
# 41   Computer Science and Engineering
# 26   Computer Science and Engineering
# 86   Computer Science and Engineering
# 36   Computer Science and Engineering
# ...

# %%
df1.sort_values(by=IITG Roll No."), 
                 
df1
# Out:
#     JEE(Adv) Roll No.  IITG Roll No.                     Name  \
# 41            2102273      200101001           AADARSHRAJ SAH
# 26            2055894      200101002       AADI AARYA CHANDRA
# 86            6110009      200101003         ABBURI CHARISHMA
# 36            2100022      200101004            ABHINAV AYUSH
# 47            3013247      200101005  ABHINAV KUMAR CHOUDHARY
# ..                ...            ...                      ...
# 40            2101321      200101110             VISHAL MEENA
# 76            6042052      200101111  YAKKALA HEMA VENKAT RAO
# 37            2100085      200101112             YASH AGARWAL
# 105           7026161      200101113                YASH GARG
# 85            6105031      200101114     YENUGONDA SUMA SHREE
#
#                             Programme
# 41   Computer Science and Engineering
# 26   Computer Science and Engineering
# 86   Computer Science and Engineering
# 36   Computer Science and Engineering
# ...

# %%
df1.sort_values(by='JEE(Adv) Roll No.') 
                 
df1
# Out:
#     JEE(Adv) Roll No.  IITG Roll No.                     Name  \
# 41            2102273      200101001           AADARSHRAJ SAH
# 26            2055894      200101002       AADI AARYA CHANDRA
# 86            6110009      200101003         ABBURI CHARISHMA
# 36            2100022      200101004            ABHINAV AYUSH
# 47            3013247      200101005  ABHINAV KUMAR CHOUDHARY
# ..                ...            ...                      ...
# 40            2101321      200101110             VISHAL MEENA
# 76            6042052      200101111  YAKKALA HEMA VENKAT RAO
# 37            2100085      200101112             YASH AGARWAL
# 105           7026161      200101113                YASH GARG
# 85            6105031      200101114     YENUGONDA SUMA SHREE
#
#                             Programme
# 41   Computer Science and Engineering
# 26   Computer Science and Engineering
# 86   Computer Science and Engineering
# 36   Computer Science and Engineering
# ...

# %%
df2=df1.reset_index()
df2
# Out:
#      index JEE(Adv) Roll No.  IITG Roll No.                     Name  \
# 0       41           2102273      200101001           AADARSHRAJ SAH
# 1       26           2055894      200101002       AADI AARYA CHANDRA
# 2       86           6110009      200101003         ABBURI CHARISHMA
# 3       36           2100022      200101004            ABHINAV AYUSH
# 4       47           3013247      200101005  ABHINAV KUMAR CHOUDHARY
# ..     ...               ...            ...                      ...
# 109     40           2101321      200101110             VISHAL MEENA
# 110     76           6042052      200101111  YAKKALA HEMA VENKAT RAO
# 111     37           2100085      200101112             YASH AGARWAL
# 112    105           7026161      200101113                YASH GARG
# 113     85           6105031      200101114     YENUGONDA SUMA SHREE
#
#                             Programme
# 0    Computer Science and Engineering
# 1    Computer Science and Engineering
# ...

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=114, step=1)

# %%
df2.index+=1
df2.index
df2
# Out:
#      index JEE(Adv) Roll No.  IITG Roll No.                     Name  \
# 1       41           2102273      200101001           AADARSHRAJ SAH
# 2       26           2055894      200101002       AADI AARYA CHANDRA
# 3       86           6110009      200101003         ABBURI CHARISHMA
# 4       36           2100022      200101004            ABHINAV AYUSH
# 5       47           3013247      200101005  ABHINAV KUMAR CHOUDHARY
# ..     ...               ...            ...                      ...
# 110     40           2101321      200101110             VISHAL MEENA
# 111     76           6042052      200101111  YAKKALA HEMA VENKAT RAO
# 112     37           2100085      200101112             YASH AGARWAL
# 113    105           7026161      200101113                YASH GARG
# 114     85           6105031      200101114     YENUGONDA SUMA SHREE
#
#                             Programme
# 1    Computer Science and Engineering
# 2    Computer Science and Engineering
# ...

# %%
df2
# Out:
#      index JEE(Adv) Roll No.  IITG Roll No.                     Name  \
# 0       41           2102273      200101001           AADARSHRAJ SAH
# 1       26           2055894      200101002       AADI AARYA CHANDRA
# 2       86           6110009      200101003         ABBURI CHARISHMA
# 3       36           2100022      200101004            ABHINAV AYUSH
# 4       47           3013247      200101005  ABHINAV KUMAR CHOUDHARY
# ..     ...               ...            ...                      ...
# 109     40           2101321      200101110             VISHAL MEENA
# 110     76           6042052      200101111  YAKKALA HEMA VENKAT RAO
# 111     37           2100085      200101112             YASH AGARWAL
# 112    105           7026161      200101113                YASH GARG
# 113     85           6105031      200101114     YENUGONDA SUMA SHREE
#
#                             Programme
# 0    Computer Science and Engineering
# 1    Computer Science and Engineering
# ...

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
df2
# Out:
#      index JEE(Adv) Roll No.  IITG Roll No.  \
# 1       41           2102273      200101001
# 2       26           2055894      200101002
# 3       86           6110009      200101003
# 4       36           2100022      200101004
# 5       47           3013247      200101005
# 6      113           7083080      200101006
# 7       52           4003180      200101007
# 8        1           1013044      200101008
# 9       54           4009314      200101009
# 10       7           1042034      200101010
# 11      38           2100351      200101011
# 12      53           4008280      200101012
# 13     110           7048092      200101013
# 14      27           2057209      200101014
# 15      30           2081373      200101015
# 16     109           7039124      200101016
# 17      61           4041137      200101017
# 18      42           2108004      200101018
# 19      95           6229003      200101019
# 20      93           6225013      200101020
# ...

# %%
df2.Name[1].split(" ")
# Out:
# ['AADARSHRAJ', 'SAH']

# %%
i=1
list=[]
while(i<=114):
    list.append(df2.Name[i].split(" "))
    i+=1

# %%
list
# Out:
# [['AADARSHRAJ', 'SAH'],
#  ['AADI', 'AARYA', 'CHANDRA'],
#  ['ABBURI', 'CHARISHMA'],
#  ['ABHINAV', 'AYUSH'],
#  ['ABHINAV', 'KUMAR', 'CHOUDHARY'],
#  ['ABHISHEK', 'KUMAR'],
#  ['ADARSH', 'MALVIYA'],
#  ['ADITYA', 'PATEL'],
#  ['ADITYA', 'PATIDAR'],
#  ['ADVAITA', 'MALLIK'],
#  ['AKSHAT', 'MITTAL'],
#  ['AMAN', 'SONI'],
#  ['AMIT', 'SINGH', 'NAGNYAL'],
#  ['AMJED', 'PARVAIZ'],
#  ['ANINDYA', 'VIJAYVARGEEYA'],
#  ['ANMOLDEEP', 'SINGH'],
#  ['ANURAG', 'RAVI'],
#  ['ARPAN', 'ANIL', 'KHANDARE'],
#  ['ARTHI', 'SAI', 'AKSHITH'],
#  ['ARYA', 'AVINASH', 'PHADKE'],
#  ['ASHWITHA', 'BANOTH'],
#  ['AYAN', 'GAUTAM'],
#  ['BACHALAKURI', 'SAMUEL', 'SUNNY', 'KUMAR'],
#  ['BHANU', 'RAJPUT'],
#  ['BILLA', 'PRAMODH'],
#  ['BOKKA', 'SRIVIDYA'],
#  ['CHIGARAPALLY', 'CHANDRABHUSHAN', 'REDDY'],
#  ['DEEP', 'KAUR'],
#  ['DHANANJAI'],
#  ['GANDRATHI', 'SRIJA'],
#  ['GANJI', 'PALA', 'VENKI', 'REDDY'],
#  ['GANNOJU', 'MANIDEEPAK'],
#  ['GAURAV', 'KUMAR'],
#  ['GHONGADE', 'ROHIT', 'KANBA'],
# ...

# %%
total=[]
for j in list:
    total+=j
total
# Out:
# ['AADARSHRAJ',
#  'SAH',
#  'AADI',
#  'AARYA',
#  'CHANDRA',
#  'ABBURI',
#  'CHARISHMA',
#  'ABHINAV',
#  'AYUSH',
#  'ABHINAV',
#  'KUMAR',
#  'CHOUDHARY',
#  'ABHISHEK',
#  'KUMAR',
#  'ADARSH',
#  'MALVIYA',
#  'ADITYA',
#  'PATEL',
#  'ADITYA',
#  'PATIDAR',
#  'ADVAITA',
#  'MALLIK',
#  'AKSHAT',
#  'MITTAL',
#  'AMAN',
#  'SONI',
#  'AMIT',
#  'SINGH',
#  'NAGNYAL',
#  'AMJED',
#  'PARVAIZ',
#  'ANINDYA',
#  'VIJAYVARGEEYA',
#  'ANMOLDEEP',
#  'SINGH',
#  'ANURAG',
#  'RAVI',
#  'ARPAN',
#  'ANIL',
#  'KHANDARE',
#  'ARTHI',
#  'SAI',
#  'AKSHITH',
#  'ARYA',
#  'AVINASH',
#  'PHADKE',
#  'ASHWITHA',
#  'BANOTH',
#  'AYAN',
#  'GAUTAM',
#  'BACHALAKURI',
#  'SAMUEL',
#  'SUNNY',
#  'KUMAR',
#  'BHANU',
#  'RAJPUT',
#  'BILLA',
#  'PRAMODH',
#  'BOKKA',
#  'SRIVIDYA',
#  'CHIGARAPALLY',
#  'CHANDRABHUSHAN',
#  'REDDY',
#  'DEEP',
#  'KAUR',
#  'DHANANJAI',
#  'GANDRATHI',
#  'SRIJA',
#  'GANJI',
#  'PALA',
#  'VENKI',
#  'REDDY',
#  'GANNOJU',
#  'MANIDEEPAK',
#  'GAURAV',
# ...

# %%
simple=set(total)
simple
# Out:
# {'AADARSHRAJ',
#  'AADI',
#  'AARYA',
#  'ABBURI',
#  'ABHINAV',
#  'ABHISHEK',
#  'ADARSH',
#  'ADITYA',
#  'ADVAITA',
#  'AGARWAL',
#  'AKSHAT',
#  'AKSHITH',
#  'AMAN',
#  'AMIT',
#  'AMJED',
#  'ANAND',
#  'ANIL',
#  'ANINDYA',
#  'ANMOLDEEP',
#  'ANURAG',
#  'ARPAN',
#  'ARTHI',
#  'ARYA',
#  'ASHISH',
#  'ASHWITHA',
#  'AVINASH',
#  'AYAN',
#  'AYUSH',
#  'BACHALAKURI',
#  'BANOTH',
#  'BANSAL',
#  'BANSODE',
#  'BARANWAL',
#  'BARLA',
#  'BHAKKAD',
#  'BHANU',
#  'BHAVESH',
#  'BHOOMIRAJ',
#  'BILLA',
#  'BOKKA',
#  'BULCHANDANI',
#  'CHAGANTI',
#  'CHANDRA',
#  'CHANDRABHUSHAN',
#  'CHARISHMA',
#  'CHIGARAPALLY',
#  'CHOUDHARY',
#  'CHOWDARY',
#  'DEEP',
#  'DHANANJAI',
#  'DHANUKA',
#  'G',
#  'GANDRATHI',
#  'GANJI',
#  'GANNOJU',
#  'GARG',
#  'GAURAV',
#  'GAUTAM',
#  'GHONGADE',
#  'GOYANKA',
#  'GUDLA',
#  'GUNDAMEEDI',
#  'GUNJAL',
#  'GUNJAN',
#  'GUPTA',
#  'H',
#  'HAREESH',
#  'HARSHITA',
#  'HARSHWARDHAN',
#  'HEEMANTH',
#  'HEMA',
#  'HEMANT',
#  'HETANG',
# ...

# %%
count = 0
for ele in simple:
        count = 0
        for p in total:
            if (ele == p): 
                count = count + 1
        if(count>1):
            print(ele,'is occuring',count,'times')
# Out:
# VISHAL is occuring 3 times
# CHOUDHARY is occuring 2 times
# RAJ is occuring 2 times
# PATEL is occuring 3 times
# RAVI is occuring 2 times
# MUKUL is occuring 2 times
# HIMANSHU is occuring 2 times
# PRANSHU is occuring 3 times
# HEMANT is occuring 2 times
# KARTIK is occuring 2 times
# SINGH is occuring 6 times
# PRANJAL is occuring 2 times
# SIDDHARTH is occuring 2 times
# YASH is occuring 2 times
# MEENA is occuring 2 times
# ADITYA is occuring 2 times
# KUMAR is occuring 11 times
# REDDY is occuring 5 times
# YADAV is occuring 2 times
# SAI is occuring 5 times
# ABHINAV is occuring 2 times
# GUPTA is occuring 2 times

# %%
df4=pd.read_csv("BTech_2020-converted.csv")
i=0
blast=[]
while(i<891):
    blast.append(df4.Name[i].split(" "))
    i+=1
total4=[]
for j4 in blast:
    total4+=j4
simple4=set(total4)
count4 = 0
for ele4 in simple4:
        count4 = 0
        for p4 in total4:
            if (ele4 == p4): 
                count4 = count4 + 1
        if(count4>1):
            print(ele4,'is occuring',count4,'times')
            
#simple4
#total4
#blast.clear()   
#blast
# Out:
# AVINASH is occuring 8 times
# NAMAN is occuring 2 times
# MEGHA is occuring 2 times
# PAL is occuring 4 times
# AMRESH is occuring 2 times
# TEJA is occuring 2 times
# RAJ is occuring 15 times
# ATHARVA is occuring 3 times
# DHUSIA is occuring 2 times
# SANJAY is occuring 3 times
# CHETAN is occuring 2 times
# VISHWAKARMA is occuring 2 times
# SURYA is occuring 2 times
# BATHULA is occuring 2 times
# KARTHIK is occuring 2 times
# PATEL is occuring 8 times
# G is occuring 2 times
# SUDIPTA is occuring 2 times
# RAVI is occuring 4 times
# SHUBHAM is occuring 3 times
# CHOUHAN is occuring 2 times
# MUKUL is occuring 2 times
# AMOGH is occuring 2 times
# KAUSHIK is occuring 2 times
# SARKAR is occuring 2 times
# ANAND is occuring 7 times
# LAKSHYA is occuring 4 times
# SYED is occuring 2 times
# SHRIDHAR is occuring 2 times
# SHRUTI is occuring 2 times
# VAMSHI is occuring 2 times
# SUMIT is occuring 2 times
# MONDAL is occuring 2 times
# SHUKLA is occuring 2 times
# ...

# %%
import matplotlib as mpt
